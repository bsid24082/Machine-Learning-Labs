# %%
from sklearn.cluster import KMeans
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from matplotlib import pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.decomposition import PCA
import numpy as np
# %matplotlib inline

# %%
df = pd.read_csv("alze.csv")
df.head()
# Out:
# /var/folders/ld/6p470m2n3rlcfrgnnk30nl340000gn/T/ipykernel_84505/2679634191.py:1: DtypeWarning: Columns (16,17) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("alze.csv")
#                                         RowId  YearStart  YearEnd  \
# 0  BRFSS~2015~2015~9001~Q27~TMC03~AGE~OVERALL       2015     2015
# 1   BRFSS~2016~2016~9001~Q03~TMC01~AGE~GENDER       2016     2016
# 2     BRFSS~2019~2019~66~Q44~TOC12~AGE~GENDER       2019     2019
# 3       BRFSS~2017~2017~25~Q32~TOC07~AGE~RACE       2017     2017
# 4       BRFSS~2020~2020~20~Q43~TOC11~AGE~RACE       2020     2020
#
#   LocationAbbr   LocationDesc Datasource           Class  \
# 0          NRE      Northeast      BRFSS   Mental Health
# 1          NRE      Northeast      BRFSS   Mental Health
# 2           GU           Guam      BRFSS  Overall Health
# 3           MA  Massachusetts      BRFSS  Overall Health
# 4           KS         Kansas      BRFSS  Overall Health
#
# ...

# %%
pd.set_option('display.max_columns', None)
df
# Out:
#                                              RowId  YearStart  YearEnd  \
# 0       BRFSS~2015~2015~9001~Q27~TMC03~AGE~OVERALL       2015     2015
# 1        BRFSS~2016~2016~9001~Q03~TMC01~AGE~GENDER       2016     2016
# 2          BRFSS~2019~2019~66~Q44~TOC12~AGE~GENDER       2019     2019
# 3            BRFSS~2017~2017~25~Q32~TOC07~AGE~RACE       2017     2017
# 4            BRFSS~2020~2020~20~Q43~TOC11~AGE~RACE       2020     2020
# ...                                            ...        ...      ...
# 250932     BRFSS~2016~2016~40~Q18~TSC08~AGE~GENDER       2016     2016
# 250933     BRFSS~2018~2018~48~Q21~TAC03~AGE~GENDER       2018     2018
# 250934       BRFSS~2018~2018~31~Q20~TSC03~AGE~RACE       2018     2018
# 250935    BRFSS~2018~2018~50~Q03~TMC01~AGE~OVERALL       2018     2018
# 250936     BRFSS~2017~2017~41~Q38~TGC03~AGE~GENDER       2017     2017
#
#        LocationAbbr   LocationDesc Datasource                    Class  \
# ...

# %%
df.isna().sum()
# Out:
# RowId                              0
# YearStart                          0
# YearEnd                            0
# LocationAbbr                       0
# LocationDesc                       0
# Datasource                         0
# Class                              0
# Topic                              0
# Question                           0
# Data_Value_Unit                    0
# DataValueTypeID                    0
# Data_Value_Type                    0
# Data_Value                     81635
# Data_Value_Alt                 81635
# Data_Value_Footnote_Symbol    151823
# Data_Value_Footnote           151823
# Low_Confidence_Limit           81785
# High_Confidence_Limit          81785
# StratificationCategory1            0
# Stratification1                    0
# StratificationCategory2        32376
# Stratification2                32376
# Geolocation                    26709
# ClassID                            0
# TopicID                            0
# ...

# %%
df = df.drop(["Data_Value_Footnote_Symbol", "Data_Value_Footnote", "RowId", "Data_Value_Unit"], axis = 1)

# %%
df.head()
# Out:
#    YearStart  YearEnd LocationAbbr   LocationDesc Datasource           Class  \
# 0       2015     2015          NRE      Northeast      BRFSS   Mental Health
# 1       2016     2016          NRE      Northeast      BRFSS   Mental Health
# 2       2019     2019           GU           Guam      BRFSS  Overall Health
# 3       2017     2017           MA  Massachusetts      BRFSS  Overall Health
# 4       2020     2020           KS         Kansas      BRFSS  Overall Health
#
#                                                Topic  \
# 0                   Lifetime diagnosis of depression
# 1                           Frequent mental distress
# 2  Severe joint pain among older adults with arth...
# 3            Self-rated health (fair to poor health)
# 4                       Arthritis among older adults
#
#                                             Question DataValueTypeID  \
# 0  Percentage of older adults with a lifetime dia...           PRCTG
# ...

# %%
df.shape
# Out:
# (250937, 27)

# %%
df.isna().mean()
# Out:
# YearStart                    0.000000
# YearEnd                      0.000000
# LocationAbbr                 0.000000
# LocationDesc                 0.000000
# Datasource                   0.000000
# Class                        0.000000
# Topic                        0.000000
# Question                     0.000000
# DataValueTypeID              0.000000
# Data_Value_Type              0.000000
# Data_Value                   0.325321
# Data_Value_Alt               0.325321
# Low_Confidence_Limit         0.325918
# High_Confidence_Limit        0.325918
# StratificationCategory1      0.000000
# Stratification1              0.000000
# StratificationCategory2      0.129020
# Stratification2              0.129020
# Geolocation                  0.106437
# ClassID                      0.000000
# TopicID                      0.000000
# QuestionID                   0.000000
# LocationID                   0.000000
# StratificationCategoryID1    0.000000
# StratificationID1            0.000000
# ...

# %%
## Finding the columns with
l=[col for col in df.columns if df[col].isnull().mean() >0.00 and df[col].isnull().mean()>0]
l
# Out:
# ['Data_Value',
#  'Data_Value_Alt',
#  'Low_Confidence_Limit',
#  'High_Confidence_Limit',
#  'StratificationCategory2',
#  'Stratification2',
#  'Geolocation']

# %%
df.tail(20)
# Out:
#         YearStart  YearEnd LocationAbbr                     LocationDesc  \
# 250917       2018     2018           OR                           Oregon
# 250918       2019     2019           WI                        Wisconsin
# 250919       2020     2020           US  United States, DC & Territories
# 250920       2015     2015         WEST                             West
# 250921       2016     2016           TX                            Texas
# 250922       2018     2018           VA                         Virginia
# 250923       2015     2015           SD                     South Dakota
# 250924       2015     2015           US  United States, DC & Territories
# 250925       2015     2015           RI                     Rhode Island
# 250926       2016     2016           OR                           Oregon
# 250927       2016     2016           NY                         New York
# 250928       2018     2018           OK                         Oklahoma
# ...

# %%
import pandas as pd

# Assuming 'df' is your pandas DataFrame

# Iterate over each column and print unique values
for column in df.columns:
    unique_values = df[column].unique()
    print() 
    print()
    print("Unique values of column '{}': {}".format(column, unique_values))
# Out:
# Unique values of column 'YearStart': [2015 2016 2019 2017 2020 2018 2021]
#
#
# Unique values of column 'YearEnd': [2015 2016 2019 2017 2020 2021 2018]
#
#
# Unique values of column 'LocationAbbr': ['NRE' 'GU' 'MA' 'KS' 'AZ' 'CO' 'AL' 'FL' 'WEST' 'MO' 'SD' 'CT' 'WA' 'AK'
#  'ME' 'OH' 'NV' 'NM' 'MDW' 'ND' 'SOU' 'DE' 'CA' 'NY' 'IN' 'RI' 'IL' 'SC'
#  'IA' 'MT' 'VA' 'US' 'MN' 'MI' 'GA' 'DC' 'MS' 'MD' 'HI' 'WY' 'ID' 'NE'
#  'KY' 'LA' 'WV' 'NJ' 'AR' 'OR' 'NC' 'PR' 'TX' 'OK' 'NH' 'WI' 'TN' 'VT'
#  'PA' 'VI' 'UT']
#
#
# Unique values of column 'LocationDesc': ['Northeast' 'Guam' 'Massachusetts' 'Kansas' 'Arizona' 'Colorado'
#  'Alabama' 'Florida' 'West' 'Missouri' 'South Dakota' 'Connecticut'
#  'Washington' 'Alaska' 'Maine' 'Ohio' 'Nevada' 'New Mexico' 'Midwest'
#  'North Dakota' 'South' 'Delaware' 'California' 'New York' 'Indiana'
#  'Rhode Island' 'Illinois' 'South Carolina' 'Iowa' 'Montana' 'Virginia'
#  'United States, DC & Territories' 'Minnesota' 'Michigan' 'Georgia'
# ...
