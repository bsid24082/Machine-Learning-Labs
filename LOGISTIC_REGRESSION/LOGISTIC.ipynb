# %%
## Importing the libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import FunctionTransformer
from sklearn.preprocessing import PowerTransformer
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer

# %%
## Importing the dataset 
df = pd.read_csv("LOANDATA.csv")
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         NaN             360.0
# 1               4583             1508.0       128.0             360.0
# 2               3000                0.0        66.0             360.0
# 3               2583             2358.0       120.0             360.0
# 4               6000                0.0       141.0             360.0
# ..               ...                ...         ...               ...
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 0               1.0         Urban           Y
# 1               1.0         Rural           N
# 2               1.0         Urban           Y
# 3               1.0         Urban           Y
# 4               1.0         Urban           Y
# ..              ...           ...         ...
# 609             1.0         Rural           Y
# 610             1.0         Rural           Y
# 611             1.0         Urban           Y
# 612             1.0         Urban           Y
# 613             0.0     Semiurban           N
#
# [614 rows x 13 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
## Checking for the null values
df.isna().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
#df.isnull().sum()
df.isnull().mean()*100
# Out:
# Loan_ID              0.000000
# Gender               2.117264
# Married              0.488599
# Dependents           2.442997
# Education            0.000000
# Self_Employed        5.211726
# ApplicantIncome      0.000000
# CoapplicantIncome    0.000000
# LoanAmount           3.583062
# Loan_Amount_Term     2.280130
# Credit_History       8.143322
# Property_Area        0.000000
# Loan_Status          0.000000
# dtype: float64

# %%
## Complete Case Analysis for Missing values less than 3% in the dataset
l=[col for col in df.columns if df[col].isnull().mean() <0.03 and df[col].isnull().mean()>0]
l
# Out:
# ['Gender', 'Married', 'Dependents', 'Loan_Amount_Term']

# %%
df.dropna(subset = l[0:4], inplace=True)

# %%
df.isnull().mean()*100
# Out:
# Loan_ID              0.000000
# Gender               0.000000
# Married              0.000000
# Dependents           0.000000
# Education            0.000000
# Self_Employed        5.410122
# ApplicantIncome      0.000000
# CoapplicantIncome    0.000000
# LoanAmount           3.490401
# Loan_Amount_Term     0.000000
# Credit_History       8.551483
# Property_Area        0.000000
# Loan_Status          0.000000
# dtype: float64

# %%
df.head(10)
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
# 5  LP001011   Male     Yes          2      Graduate           Yes
# 6  LP001013   Male     Yes          0  Not Graduate            No
# 7  LP001014   Male     Yes         3+      Graduate            No
# 8  LP001018   Male     Yes          2      Graduate            No
# 9  LP001020   Male     Yes          1      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
# 5             5417             4196.0       267.0             360.0
# 6             2333             1516.0        95.0             360.0
# 7             3036             2504.0       158.0             360.0
# 8             4006             1526.0       168.0             360.0
# 9            12841            10968.0       349.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y
# 3             1.0         Urban           Y
# 4             1.0         Urban           Y
# 5             1.0         Urban           Y
# 6             1.0         Urban           Y
# 7             0.0     Semiurban           N
# 8             1.0         Urban           Y
# 9             1.0     Semiurban           N

# %%
plt.figure(figsize=(14,4))

plt.subplot(121)
sns.histplot(df['Dependents'])
plt.title('No. of Dependents in Family')
# Out:
# Text(0.5, 1.0, 'No. of Dependents in Family')

# %%
plt.figure(figsize=(14,4))

plt.subplot(122)
sns.histplot(df['ApplicantIncome'])
plt.title('Applicant-Income')
# Out:
# Text(0.5, 1.0, 'Applicant-Income')

# %%
plt.figure(figsize=(14,4))

plt.subplot(121)
sns.histplot(df['Self_Employed'])
plt.title('If Self-Employed')
# Out:
# Text(0.5, 1.0, 'If Self-Employed')

# %%
df.isnull().mean()*100
# Out:
# Loan_ID              0.000000
# Gender               0.000000
# Married              0.000000
# Dependents           0.000000
# Education            0.000000
# Self_Employed        5.410122
# ApplicantIncome      0.000000
# CoapplicantIncome    0.000000
# LoanAmount           3.490401
# Loan_Amount_Term     0.000000
# Credit_History       8.551483
# Property_Area        0.000000
# Loan_Status          0.000000
# dtype: float64

# %%
def random_sampling_imputation(column):          
    non_missing_values = df[column].dropna()        
    random_samples = np.random.choice(non_missing_values, size=df[column].isnull().sum(), replace=True)
    df.loc[df[column].isnull(),column] = random_samples

# %%
random_sampling_imputation("Self_Employed")

# %%
df.isnull().mean()*100
# Out:
# Loan_ID              0.000000
# Gender               0.000000
# Married              0.000000
# Dependents           0.000000
# Education            0.000000
# Self_Employed        0.000000
# ApplicantIncome      0.000000
# CoapplicantIncome    0.000000
# LoanAmount           3.490401
# Loan_Amount_Term     0.000000
# Credit_History       8.551483
# Property_Area        0.000000
# Loan_Status          0.000000
# dtype: float64

# %%
plt.figure(figsize=(14,4))

plt.subplot(121)
sns.histplot(df['Self_Employed'])
plt.title('If Self-Employed')
# Out:
# Text(0.5, 1.0, 'If Self-Employed')

# %%
plt.figure(figsize=(14,4))

plt.subplot(121)
sns.histplot(df['LoanAmount'])
plt.title('LoanAmount')
# Out:
# Text(0.5, 1.0, 'LoanAmount')

# %%
df['LoanAmount'].fillna(df['LoanAmount'].median(),inplace=True)

# %%
df.isnull().mean()*100
# Out:
# Loan_ID              0.000000
# Gender               0.000000
# Married              0.000000
# Dependents           0.000000
# Education            0.000000
# Self_Employed        0.000000
# ApplicantIncome      0.000000
# CoapplicantIncome    0.000000
# LoanAmount           0.000000
# Loan_Amount_Term     0.000000
# Credit_History       8.551483
# Property_Area        0.000000
# Loan_Status          0.000000
# dtype: float64

# %%
plt.figure(figsize=(14,4))
plt.subplot(121)
sns.histplot(df['Credit_History'])
plt.title('Credit_History')
# Out:
# Text(0.5, 1.0, 'Credit_History')

# %%
random_sampling_imputation("Credit_History")

# %%
plt.figure(figsize=(14,4))
plt.subplot(121)
sns.histplot(df['Credit_History'])
plt.title('Credit_History')
# Out:
# Text(0.5, 1.0, 'Credit_History')

# %%
### The missing values have been dealt with.
df.isnull().mean()*100
# Out:
# Loan_ID              0.0
# Gender               0.0
# Married              0.0
# Dependents           0.0
# Education            0.0
# Self_Employed        0.0
# ApplicantIncome      0.0
# CoapplicantIncome    0.0
# LoanAmount           0.0
# Loan_Amount_Term     0.0
# Credit_History       0.0
# Property_Area        0.0
# Loan_Status          0.0
# dtype: float64

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0       128.0             360.0
# 1               4583             1508.0       128.0             360.0
# 2               3000                0.0        66.0             360.0
# 3               2583             2358.0       120.0             360.0
# 4               6000                0.0       141.0             360.0
# ..               ...                ...         ...               ...
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 0               1.0         Urban           Y
# 1               1.0         Rural           N
# 2               1.0         Urban           Y
# 3               1.0         Urban           Y
# 4               1.0         Urban           Y
# ..              ...           ...         ...
# 609             1.0         Rural           Y
# 610             1.0         Rural           Y
# 611             1.0         Urban           Y
# 612             1.0         Urban           Y
# 613             0.0     Semiurban           N
#
# [573 rows x 13 columns]

# %% [markdown]
# ## Encoding

# %%
## Checking the unique values in the columns
df['Gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df.isna().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
from sklearn.preprocessing import OneHotEncoder
ohe = OneHotEncoder()
data = ohe.fit_transform(df[['Gender']])
## To convert the data into an array to deal with value error.
data = data.toarray()

ef = pd.DataFrame(data, columns=['Male', 'Female'])
ef
df = pd.concat([df,ef], axis = 1)
df
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001002   Male      No          0      Graduate            No
# 1    LP001003   Male     Yes          1      Graduate            No
# 2    LP001005   Male     Yes          0      Graduate           Yes
# 3    LP001006   Male     Yes          0  Not Graduate            No
# 4    LP001008   Male      No          0      Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 467       NaN    NaN     NaN        NaN           NaN           NaN
# 477       NaN    NaN     NaN        NaN           NaN           NaN
# 507       NaN    NaN     NaN        NaN           NaN           NaN
# 517       NaN    NaN     NaN        NaN           NaN           NaN
# 571       NaN    NaN     NaN        NaN           NaN           NaN
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849.0                0.0       128.0             360.0
# 1             4583.0             1508.0       128.0             360.0
# 2             3000.0                0.0        66.0             360.0
# 3             2583.0             2358.0       120.0             360.0
# 4             6000.0                0.0       141.0             360.0
# ..               ...                ...         ...               ...
# 467              NaN                NaN         NaN               NaN
# 477              NaN                NaN         NaN               NaN
# 507              NaN                NaN         NaN               NaN
# 517              NaN                NaN         NaN               NaN
# 571              NaN                NaN         NaN               NaN
#
#      Credit_History Property_Area Loan_Status  Male  Female
# 0               1.0         Urban           Y   0.0     1.0
# 1               1.0         Rural           N   0.0     1.0
# 2               1.0         Urban           Y   0.0     1.0
# 3               1.0         Urban           Y   0.0     1.0
# 4               1.0         Urban           Y   0.0     1.0
# ..              ...           ...         ...   ...     ...
# 467             NaN           NaN         NaN   1.0     0.0
# 477             NaN           NaN         NaN   0.0     1.0
# 507             NaN           NaN         NaN   0.0     1.0
# 517             NaN           NaN         NaN   0.0     1.0
# 571             NaN           NaN         NaN   0.0     1.0
#
# [610 rows x 15 columns]

# %%
## Checking the unique values in the columns
df['Married'].unique()
# Out:
# array(['No', 'Yes', nan], dtype=object)

# %%
from sklearn.preprocessing import OneHotEncoder
ohe = OneHotEncoder()
data = ohe.fit_transform(df[['Married']])
## To convert the data into an array to deal with value error.
data = data.toarray()

ef = pd.DataFrame(data, columns=['Not_Married', 'is_Married'])
ef
df = pd.concat([df,ef], axis = 1)
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [31], in <cell line: 7>()
#       4 ## To convert the data into an array to deal with value error.
#       5 data = data.toarray()
# ----> 7 ef = pd.DataFrame(data, columns=['Not_Married', 'is_Married'])
#       8 ef
#       9 df = pd.concat([df,ef], axis = 1)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:694, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     684         mgr = dict_to_mgr(
#     685             # error: Item "ndarray" of "Union[ndarray, Series, Index]" has no
#     686             # attribute "name"
#    (...)
#     691             typ=manager,
#     692         )
#     693     else:
# --> 694         mgr = ndarray_to_mgr(
#     695             data,
#     696             index,
#     697             columns,
#     698             dtype=dtype,
#     699             copy=copy,
#     700             typ=manager,
#     701         )
#     703 # For data is list-like, or Iterable (will consume into list)
#     704 elif is_list_like(data):
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/construction.py:351, in ndarray_to_mgr(values, index, columns, dtype, copy, typ)
#     346 # _prep_ndarray ensures that values.ndim == 2 at this point
#     347 index, columns = _get_axes(
#     348     values.shape[0], values.shape[1], index=index, columns=columns
#     349 )
# --> 351 _check_values_indices_shape_match(values, index, columns)
#     353 if typ == "array":
#     355     if issubclass(values.dtype.type, str):
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/construction.py:422, in _check_values_indices_shape_match(values, index, columns)
#     420 passed = values.shape
#     421 implied = (len(index), len(columns))
# --> 422 raise ValueError(f"Shape of passed values is {passed}, indices imply {implied}")
#
# ValueError: Shape of passed values is (610, 3), indices imply (610, 2)

# %%
## Checking the unique values in the columns
df['Education'].unique()

# %%
from sklearn.preprocessing import OneHotEncoder
ohe = OneHotEncoder()
data = ohe.fit_transform(df[['Education']])
## To convert the data into an array to deal with value error.
data = data.toarray()

ef = pd.DataFrame(data, columns=['is_Graduate', 'Not_Graduate'])
ef
df = pd.concat([df,ef], axis = 1)
df

# %%
## Checking the unique values in the columns
df['Property_Area'].unique()

# %%
from sklearn.preprocessing import OrdinalEncoder

encoder = OrdinalEncoder(categories=[['Urban', 'Semiurban', 'Rural']])
df['Property_Area'] = encoder.fit_transform(df[['Property_Area']])
df['Property_Area'].unique()

# %%
df

# %%
## Checking the unique values in the columns
df['Self_Employed'].unique()

# %%
from sklearn.preprocessing import OneHotEncoder
ohe = OneHotEncoder()
data = ohe.fit_transform(df[['Self_Employed']])
## To convert the data into an array to deal with value error.
data = data.toarray()

ef = pd.DataFrame(data, columns=['is_Self_Employed', 'Not_Self_Employed'])
ef
df = pd.concat([df,ef], axis = 1)
df

# %%
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()
df['Loan_Status'] = label_encoder.fit_transform(df['Loan_Status'])
df['Loan_Status'].unique()

# %%
df

# %%
df['Dependents'].unique()

# %%
from sklearn.preprocessing import OneHotEncoder
ohe = OneHotEncoder()
data = ohe.fit_transform(df[['Dependents']])
## To convert the data into an array to deal with value error.
data = data.toarray()

ef = pd.DataFrame(data, columns=['Zero_Dep', 'One_Dep', 'Two_Dep', 'Three_more_Dep'])
ef
df = pd.concat([df,ef], axis = 1)
df

# %%
df = df.drop(['Gender', 'Married', 'Education', 'Self_Employed', 'Loan_ID', 'Dependents'], axis = 1)

# %%
df

# %%
df.isnull().mean()*100

# %%
df
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001002   Male      No          0      Graduate            No
# 1    LP001003   Male     Yes          1      Graduate            No
# 2    LP001005   Male     Yes          0      Graduate           Yes
# 3    LP001006   Male     Yes          0  Not Graduate            No
# 4    LP001008   Male      No          0      Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 467       NaN    NaN     NaN        NaN           NaN           NaN
# 477       NaN    NaN     NaN        NaN           NaN           NaN
# 507       NaN    NaN     NaN        NaN           NaN           NaN
# 517       NaN    NaN     NaN        NaN           NaN           NaN
# 571       NaN    NaN     NaN        NaN           NaN           NaN
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849.0                0.0       128.0             360.0
# 1             4583.0             1508.0       128.0             360.0
# 2             3000.0                0.0        66.0             360.0
# 3             2583.0             2358.0       120.0             360.0
# 4             6000.0                0.0       141.0             360.0
# ..               ...                ...         ...               ...
# 467              NaN                NaN         NaN               NaN
# 477              NaN                NaN         NaN               NaN
# 507              NaN                NaN         NaN               NaN
# 517              NaN                NaN         NaN               NaN
# 571              NaN                NaN         NaN               NaN
#
#      Credit_History Property_Area Loan_Status  Male  Female
# 0               1.0         Urban           Y   0.0     1.0
# 1               1.0         Rural           N   0.0     1.0
# 2               1.0         Urban           Y   0.0     1.0
# 3               1.0         Urban           Y   0.0     1.0
# 4               1.0         Urban           Y   0.0     1.0
# ..              ...           ...         ...   ...     ...
# 467             NaN           NaN         NaN   1.0     0.0
# 477             NaN           NaN         NaN   0.0     1.0
# 507             NaN           NaN         NaN   0.0     1.0
# 517             NaN           NaN         NaN   0.0     1.0
# 571             NaN           NaN         NaN   0.0     1.0
#
# [610 rows x 15 columns]
